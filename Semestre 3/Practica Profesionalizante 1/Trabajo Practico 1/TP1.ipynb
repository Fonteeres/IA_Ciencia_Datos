# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
df_poblT = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Practica Profesionalizante 1/Primer Tp/WPP2019_TotalPopulationBySex.csv')
df_poblT
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0           4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1           4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2           4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3           4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4           4  Afghanistan      2       Medium  1954     1954.5   4266.484
# ...       ...          ...    ...          ...   ...        ...        ...
# 280927    716     Zimbabwe    207  Lower 95 PI  2080     2080.5  10576.533
# 280928    716     Zimbabwe    207  Lower 95 PI  2085     2085.5  10293.349
# 280929    716     Zimbabwe    207  Lower 95 PI  2090     2090.5   9920.336
# 280930    716     Zimbabwe    207  Lower 95 PI  2095     2095.5   9503.711
# 280931    716     Zimbabwe    207  Lower 95 PI  2100     2100.5   9090.075
#
#         PopFemale   PopTotal  PopDensity
# 0        3652.874   7752.117      11.874
# 1        3705.395   7840.151      12.009
# 2        3761.546   7935.996      12.156
# 3        3821.348   8039.684      12.315
# 4        3884.832   8151.316      12.486
# ...           ...        ...         ...
# 280927  11255.983  21836.893      56.448
# 280928  11050.875  21355.988      55.205
# 280929  10767.709  20689.956      53.483
# 280930  10412.184  19892.080      51.421
# 280931   9996.105  19061.177      49.273
#
# [280932 rows x 10 columns]

# %% [markdown]
# 1.  ¿Qué países tienen datos faltantes?
# 2.  ¿Cuál es la tasa de crecimiento poblacional anual media para todos los países en el intervalo 2000-2020?
# 3. ¿Cuáles son los 10 países que tienen mayor tasa de crecimiento poblacional anual media en ese periodo? ¿Y los que tienen la menor? (Ojo! Por ahora, sólo considerar los países para los que tenemos datos completos para el periodo indicado)
# 4.¿Podría presentar algunas gráficas descriptivas?
#   * Población anual argentina en el periodo 2000-2020
#   * Lo mismo que antes pero discriminando varones y mujeres
#   * Si sólo consideramos argentina y sus países limítrofes: ¿podríamos hacer un gráfico que represente la "proporción" que cada uno lleva con su población actual? ¿Qué tipo de gráfico les parece que sería adecuado para representar esa información?

# %% [markdown]
# Analiza el archivo manualmente de varias formas y verificar que tipo de codificacion

# %%
df_poblT.columns
# Out:
# Index(['LocID', 'Location', 'VarID', 'Variant', 'Time', 'MidPeriod', 'PopMale',
#        'PopFemale', 'PopTotal', 'PopDensity'],
#       dtype='object')

# %%
df_poblT.index
# Out:
# RangeIndex(start=0, stop=280932, step=1)

# %% [markdown]
# Hice que cuente todas las columnas y me devuelva todas aquellas que estan llenas. de esta forma me doy cuenta que en PopMale y PopFemale hay datos faltantes

# %%
df_poblT.dtypes
# Out:
# LocID           int64
# Location       object
# VarID           int64
# Variant        object
# Time            int64
# MidPeriod     float64
# PopMale       float64
# PopFemale     float64
# PopTotal      float64
# PopDensity    float64
# dtype: object

# %%
df_poblT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280932 entries, 0 to 280931
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   LocID       280932 non-null  int64
#  1   Location    280932 non-null  object
#  2   VarID       280932 non-null  int64
#  3   Variant     280932 non-null  object
#  4   Time        280932 non-null  int64
#  5   MidPeriod   280932 non-null  float64
#  6   PopMale     250876 non-null  float64
#  7   PopFemale   250876 non-null  float64
#  8   PopTotal    280932 non-null  float64
#  9   PopDensity  280932 non-null  float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 21.4+ MB

# %%
df_poblT.isnull().any()
# Out:
# LocID         False
# Location      False
# VarID         False
# Variant       False
# Time          False
# MidPeriod     False
# PopMale        True
# PopFemale      True
# PopTotal      False
# PopDensity    False
# dtype: bool

# %%
df_poblT.describe()
# Out:
#                LocID          VarID           Time      MidPeriod  \
# count  280932.000000  280932.000000  280932.000000  280932.000000
# mean      703.125062      22.411345    2051.026494    2051.526494
# std       631.959759      55.972847      33.642148      33.642148
# min         4.000000       2.000000    1950.000000    1950.500000
# 25%       300.000000       2.000000    2031.000000    2031.500000
# 50%       586.000000       5.000000    2055.000000    2055.500000
# 75%       903.000000       9.000000    2078.000000    2078.500000
# max      5501.000000     207.000000    2100.000000    2100.500000
#
#             PopMale     PopFemale      PopTotal     PopDensity
# count  2.508760e+05  2.508760e+05  2.809320e+05  280932.000000
# mean   2.324362e+05  2.298754e+05  4.128536e+05     426.659040
# std    6.938837e+05  6.829825e+05  1.308911e+06    2418.990784
# min    6.812000e+00  6.889000e+00  1.510000e-01       0.052000
# 25%    1.847834e+03  1.860604e+03  1.240100e+03      34.205250
# 50%    1.136849e+04  1.164585e+04  1.420555e+04      91.590000
# 75%    8.526402e+04  8.648854e+04  1.171661e+05     216.985750
# max    1.092000e+07  1.071273e+07  2.163274e+07   56025.839000

# %% [markdown]
# Busco iterar todo el data set buscando los datos vacios y que me guarde el nombre del pais de aquellos que si lo estan.

# %%
df_poblT = df_poblT.loc[(df_poblT['Variant'] == 'Medium')& (df_poblT['LocID'] <= 500 )]
df_poblT
# Out:
#         LocID            Location  VarID Variant  Time  MidPeriod   PopMale  \
# 0           4         Afghanistan      2  Medium  1950     1950.5  4099.243
# 1           4         Afghanistan      2  Medium  1951     1951.5  4134.756
# 2           4         Afghanistan      2  Medium  1952     1952.5  4174.450
# 3           4         Afghanistan      2  Medium  1953     1953.5  4218.336
# 4           4         Afghanistan      2  Medium  1954     1954.5  4266.484
# ...       ...                 ...    ...     ...   ...        ...       ...
# 236831    275  State of Palestine      2  Medium  2096     2096.5  6175.152
# 236832    275  State of Palestine      2  Medium  2097     2097.5  6186.855
# 236833    275  State of Palestine      2  Medium  2098     2098.5  6197.416
# 236834    275  State of Palestine      2  Medium  2099     2099.5  6206.801
# 236835    275  State of Palestine      2  Medium  2100     2100.5  6214.996
#
#         PopFemale   PopTotal  PopDensity
# 0        3652.874   7752.117      11.874
# 1        3705.395   7840.151      12.009
# 2        3761.546   7935.996      12.156
# 3        3821.348   8039.684      12.315
# 4        3884.832   8151.316      12.486
# ...           ...        ...         ...
# 236831   6016.180  12191.332    2025.138
# 236832   6026.994  12213.849    2028.879
# 236833   6036.784  12234.200    2032.259
# 236834   6045.518  12252.319    2035.269
# 236835   6053.222  12268.218    2037.910
#
# [20385 rows x 10 columns]

# %% [markdown]
# ##1.  ¿Qué países tienen datos faltantes?

# %%
df_poblT2 = df_poblT.loc[(df_poblT['PopMale'].isna()==True) & (df_poblT['PopFemale'].isna()==True)]
df_poblT2
# Out:
#         LocID        Location  VarID Variant  Time  MidPeriod  PopMale  \
# 4744       16  American Samoa      2  Medium  1950     1950.5      NaN
# 4745       16  American Samoa      2  Medium  1951     1951.5      NaN
# 4746       16  American Samoa      2  Medium  1952     1952.5      NaN
# 4747       16  American Samoa      2  Medium  1953     1953.5      NaN
# 4748       16  American Samoa      2  Medium  1954     1954.5      NaN
# ...       ...             ...    ...     ...   ...        ...      ...
# 166325    500      Montserrat      2  Medium  2096     2096.5      NaN
# 166326    500      Montserrat      2  Medium  2097     2097.5      NaN
# 166327    500      Montserrat      2  Medium  2098     2098.5      NaN
# 166328    500      Montserrat      2  Medium  2099     2099.5      NaN
# 166329    500      Montserrat      2  Medium  2100     2100.5      NaN
#
#         PopFemale  PopTotal  PopDensity
# 4744          NaN    18.941      94.705
# 4745          NaN    19.287      96.435
# 4746          NaN    19.546      97.730
# 4747          NaN    19.699      98.495
# 4748          NaN    19.758      98.790
# ...           ...       ...         ...
# 166325        NaN     2.952      29.520
# 166326        NaN     2.930      29.300
# 166327        NaN     2.911      29.110
# 166328        NaN     2.891      28.910
# 166329        NaN     2.878      28.780
#
# [2265 rows x 10 columns]

# %%
a = set(df_poblT2['Location'])
print(a)
# Out:
# {'Falkland Islands (Malvinas)', 'Bermuda', 'Faroe Islands', 'Holy See', 'Cayman Islands', 'American Samoa', 'Andorra', 'Montserrat', 'Dominica', 'Liechtenstein', 'British Virgin Islands', 'Greenland', 'Cook Islands', 'Monaco', 'Gibraltar'}

# %% [markdown]
# ##2.¿Cuál es la tasa de crecimiento poblacional anual media para todos los países en el intervalo 2000-2020?
#
# 1.   crear un df con el intervalo del 2000 al 2020 de todos los paises
# 2. Usar un shift para hacer que todos los valores de la columna 'PopTotal' bajen una fila
# 3. Antes del shift separa por grupos para que los valores de la pob total de el pais que no corresponde se mezcle con la de otros paises
# 2.   luego introducir esos datos a una funcion para calcular la tasa
# 3.   crear una nueva columna con la tasa en este df

# %%
#Cree el DF se guarda unicamente las filas que cumples con la condicion de estar entre 2000 y 2021
df_Intervalo = df_poblT.loc[(df_poblT['Time'] >= 2000) & (df_poblT['Time'] < 2021) ]
df_Intervalo
# Out:
#         LocID            Location  VarID Variant  Time  MidPeriod    PopMale  \
# 50          4         Afghanistan      2  Medium  2000     2000.5  10689.508
# 51          4         Afghanistan      2  Medium  2001     2001.5  11117.754
# 52          4         Afghanistan      2  Medium  2002     2002.5  11642.106
# 53          4         Afghanistan      2  Medium  2003     2003.5  12214.634
# 54          4         Afghanistan      2  Medium  2004     2004.5  12763.726
# ...       ...                 ...    ...     ...   ...        ...        ...
# 236751    275  State of Palestine      2  Medium  2016     2016.5   2352.012
# 236752    275  State of Palestine      2  Medium  2017     2017.5   2408.294
# 236753    275  State of Palestine      2  Medium  2018     2018.5   2466.617
# 236754    275  State of Palestine      2  Medium  2019     2019.5   2526.350
# 236755    275  State of Palestine      2  Medium  2020     2020.5   2586.971
#
#         PopFemale   PopTotal  PopDensity
# 50      10090.449  20779.957      31.829
# 51      10489.238  21606.992      33.096
# 52      10958.668  22600.774      34.618
# 53      11466.237  23680.871      36.273
# 54      11962.963  24726.689      37.874
# ...           ...        ...         ...
# 236751   2283.632   4635.644     770.041
# 236752   2338.939   4747.233     788.577
# 236753   2396.361   4862.978     807.804
# 236754   2455.072   4981.422     827.479
# 236755   2514.445   5101.416     847.411
#
# [2835 rows x 10 columns]

# %%
df_Intervalo['PopTotalShifteada'] = df_Intervalo.groupby('Location')['PopTotal'].shift()
df_Intervalo['%TasaDeCrecimiento'] = ((df_Intervalo['PopTotal'] / df_Intervalo['PopTotalShifteada'])- 1)*100
df_Intervalo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         LocID            Location  VarID Variant  Time  MidPeriod    PopMale  \
# 50          4         Afghanistan      2  Medium  2000     2000.5  10689.508
# 51          4         Afghanistan      2  Medium  2001     2001.5  11117.754
# 52          4         Afghanistan      2  Medium  2002     2002.5  11642.106
# 53          4         Afghanistan      2  Medium  2003     2003.5  12214.634
# 54          4         Afghanistan      2  Medium  2004     2004.5  12763.726
# ...       ...                 ...    ...     ...   ...        ...        ...
# 236751    275  State of Palestine      2  Medium  2016     2016.5   2352.012
# 236752    275  State of Palestine      2  Medium  2017     2017.5   2408.294
# 236753    275  State of Palestine      2  Medium  2018     2018.5   2466.617
# 236754    275  State of Palestine      2  Medium  2019     2019.5   2526.350
# 236755    275  State of Palestine      2  Medium  2020     2020.5   2586.971
#
#         PopFemale   PopTotal  PopDensity  PopTotalShifteada  \
# 50      10090.449  20779.957      31.829                NaN
# 51      10489.238  21606.992      33.096          20779.957
# 52      10958.668  22600.774      34.618          21606.992
# 53      11466.237  23680.871      36.273          22600.774
# 54      11962.963  24726.689      37.874          23680.871
# ...           ...        ...         ...                ...
# 236751   2283.632   4635.644     770.041           4529.160
# 236752   2338.939   4747.233     788.577           4635.644
# 236753   2396.361   4862.978     807.804           4747.233
# 236754   2455.072   4981.422     827.479           4862.978
# 236755   2514.445   5101.416     847.411           4981.422
#
#         %TasaDeCrecimiento
# 50                     NaN
# 51                3.979965
# 52                4.599354
# 53                4.779027
# 54                4.416299
# ...                    ...
# 236751            2.351076
# 236752            2.407195
# 236753            2.438157
# 236754            2.435627
# 236755            2.408830
#
# [2835 rows x 12 columns]

# %% [markdown]
# ##3.¿Cuáles son los 10 países que tienen mayor tasa de crecimiento poblacional anual media en ese periodo? ¿Y los que tienen la menor?
# ¿Cuáles son los 10 países que tienen mayor tasa de crecimiento poblacional anual media en ese periodo? ¿Y los que tienen la menor? (Ojo! Por ahora, sólo considerar los países para los que tenemos datos completos para el periodo indicado)

# %%
df_Porcentaje = df_Intervalo.groupby('Location')['%TasaDeCrecimiento'].sum()
df_Porcentaje.sort_values(ascending=False).head(10)
# Out:
# Location
# Bahrain                             96.653026
# Equatorial Guinea                   85.717552
# Kuwait                              75.302872
# Angola                              70.770032
# Jordan                              70.321298
# Chad                                68.754825
# Maldives                            67.175276
# Democratic Republic of the Congo    65.298135
# Afghanistan                         63.825920
# Burundi                             63.262451
# Name: %TasaDeCrecimiento, dtype: float64

# %%
df_Porcentaje.sort_values(ascending=False).tail(10)
# Out:
# Location
# Estonia                   -5.310422
# Hungary                   -5.628613
# Greece                    -6.109023
# Croatia                   -7.551915
# Albania                   -8.347477
# Georgia                   -8.909869
# Bosnia and Herzegovina   -13.311240
# Bulgaria                 -14.016932
# Latvia                   -23.290883
# Lithuania                -25.018743
# Name: %TasaDeCrecimiento, dtype: float64

# %% [markdown]
# ##4.¿Podría presentar algunas gráficas descriptivas?
# 1. Población anual argentina en el periodo 2000-2020
# 2. Lo mismo que antes pero discriminando varones y mujeres
# 3. Si sólo consideramos argentina y sus países limítrofes: ¿podríamos hacer un gráfico que represente la "proporción" que cada uno lleva con su población actual? ¿Qué tipo de gráfico les parece que sería adecuado para representar esa información?

# %%
#Primero separemos los datos
Arg = df_poblT[(df_poblT['Location'] == 'Argentina') & (df_poblT['Time']>=2000) & (df_poblT['Time']<=2020)]
Arg
# Out:
#       LocID   Location  VarID Variant  Time  MidPeriod    PopMale  PopFemale  \
# 9365     32  Argentina      2  Medium  2000     2000.5  17894.725  18976.071
# 9366     32  Argentina      2  Medium  2001     2001.5  18090.636  19185.008
# 9367     32  Argentina      2  Medium  2002     2002.5  18290.786  19390.957
# 9368     32  Argentina      2  Medium  2003     2003.5  18493.545  19594.321
# 9369     32  Argentina      2  Medium  2004     2004.5  18696.321  19795.649
# 9370     32  Argentina      2  Medium  2005     2005.5  18897.365  19995.559
# 9371     32  Argentina      2  Medium  2006     2006.5  19095.976  20193.900
# 9372     32  Argentina      2  Medium  2007     2007.5  19293.169  20391.134
# 9373     32  Argentina      2  Medium  2008     2008.5  19490.949  20589.210
# 9374     32  Argentina      2  Medium  2009     2009.5  19692.182  20790.604
# 9375     32  Argentina      2  Medium  2010     2010.5  19898.751  20997.000
# 9376     32  Argentina      2  Medium  2011     2011.5  20111.326  21209.171
# 9377     32  Argentina      2  Medium  2012     2012.5  20328.844  21426.344
# 9378     32  Argentina      2  Medium  2013     2013.5  20549.388  21646.646
# 9379     32  Argentina      2  Medium  2014     2014.5  20770.186  21867.322
# 9380     32  Argentina      2  Medium  2015     2015.5  20989.150  22086.266
# 9381     32  Argentina      2  Medium  2016     2016.5  21205.599  22302.860
# 9382     32  Argentina      2  Medium  2017     2017.5  21419.801  22517.342
# 9383     32  Argentina      2  Medium  2018     2018.5  21631.673  22729.477
# 9384     32  Argentina      2  Medium  2019     2019.5  21841.415  22939.260
# 9385     32  Argentina      2  Medium  2020     2020.5  22049.146  23146.631
#
#        PopTotal  PopDensity
# 9365  36870.796      13.473
# 9366  37275.644      13.621
# 9367  37681.743      13.769
# 9368  38087.866      13.917
# 9369  38491.970      14.065
# 9370  38892.924      14.212
# 9371  39289.876      14.357
# 9372  39684.303      14.501
# 9373  40080.159      14.645
# 9374  40482.786      14.793
# 9375  40895.751      14.944
# 9376  41320.497      15.099
# 9377  41755.188      15.258
# 9378  42196.034      15.419
# 9379  42637.508      15.580
# 9380  43075.416      15.740
# 9381  43508.459      15.898
# 9382  43937.143      16.055
# 9383  44361.150      16.210
# 9384  44780.675      16.363
# 9385  45195.777      16.515

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = Arg['PopTotal']
y = Arg['Time']
ax.plot(x, y, linewidth=3.0)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(15, 6))
sns.set_color_codes("pastel")
sns.barplot(x=Arg['Time'], y=Arg['PopTotal'], data=Arg,label="Mujeres", color="b")

# %%
f, ax = plt.subplots(figsize=(15, 6))
sns.set_color_codes("pastel")
sns.barplot(x=Arg['Time'], y=Arg['PopTotal'], data=Arg,label="Mujeres", color="b")
sns.set_color_codes("muted")
sns.barplot(x=Arg['Time'], y=Arg['PopMale'], data=Arg,label="Hombres", color="b")
ax.legend(ncol=1, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Poblacion Argentina entre 2000/2020")
sns.despine(left=True, bottom=True)

# %%
paisesLimitrofes= [32,152,68,600, 76,858]
dfLimitrofes=df_poblT[df_poblT.LocID.isin(paisesLimitrofes)]
dfLimitrofes=dfLimitrofes.loc[df_poblT['Variant'] =='Medium']
dfLimitrofes=dfLimitrofes.loc[df_poblT['Time'] ==2022]
dfLimitrofes
# Out:
#        LocID                          Location  VarID Variant  Time  \
# 9387      32                         Argentina      2  Medium  2022
# 27262     68  Bolivia (Plurinational State of)      2  Medium  2022
# 30798     76                            Brazil      2  Medium  2022
# 47012    152                             Chile      2  Medium  2022
#
#        MidPeriod     PopMale   PopFemale    PopTotal  PopDensity
# 9387      2022.5   22457.413   23552.821   46010.234      16.812
# 27262     2022.5    6014.723    5977.924   11992.647      11.070
# 30798     2022.5  105731.316  109622.272  215353.588      25.766
# 47012     2022.5    9495.704    9754.488   19250.192      25.890

# %%
import matplotlib.pyplot as plt

cant = dfLimitrofes['PopTotal']
nombres = dfLimitrofes["Location"]
plt.pie(cant, labels=nombres)
plt.show()
