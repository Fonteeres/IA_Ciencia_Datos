# %% [markdown]
# #Preprocesamiento

# %% [markdown]
# #### Ejercicio 1
#
# Supongamos que tenemos el dataframe dfB, y queremos imputar o asignar el valor de la **mediana** a los valores nulos (nan) de todas sus columnas.
# Al imputador llámelo imputador1 y guarde los resultados ya transformados en un DataFrame denominado dfB_Transformado.

# %%
dfB=pd.DataFrame([[1,5,4,3],[np.nan,3,2,np.nan],[7,np.nan,0,4],[4,2,4,1],[3,0,np.nan,8],[2,7,5,4]])
dfB.columns=['col1','col2','col3','col4']
dfB
# Out:
#    col1  col2  col3  col4
# 0   1.0   5.0   4.0   3.0
# 1   NaN   3.0   2.0   NaN
# 2   7.0   NaN   0.0   4.0
# 3   4.0   2.0   4.0   1.0
# 4   3.0   0.0   NaN   8.0
# 5   2.0   7.0   5.0   4.0

# %%
imputador1 = SimpleImputer(strategy='median')#Creo el modelo
imputador1.fit(dfB)#Lo entreno con los datos que quiero
# Out:
# SimpleImputer(strategy='median')

# %%
imputador1.statistics_#Observo los datos para estar seguro
# Out:
# array([3., 3., 4., 4.])

# %%
ArrayB_Transformado = imputador1.transform(dfB)# Creo un array de los nuevos datos
ArrayB_Transformado# lo visualizo
# Out:
# array([[1., 5., 4., 3.],
#        [3., 3., 2., 4.],
#        [7., 3., 0., 4.],
#        [4., 2., 4., 1.],
#        [3., 0., 4., 8.],
#        [2., 7., 5., 4.]])

# %%
dfB_transformado = pd.DataFrame(ArrayB_Transformado, columns=dfB.columns) # Creo el DF con los datos del array y Le asigno las columnas del viejo DF
dfB_transformado # Lo muestro
# Out:
#    col1  col2  col3  col4
# 0   1.0   5.0   4.0   3.0
# 1   3.0   3.0   2.0   4.0
# 2   7.0   3.0   0.0   4.0
# 3   4.0   2.0   4.0   1.0
# 4   3.0   0.0   4.0   8.0
# 5   2.0   7.0   5.0   4.0

# %% [markdown]
# En forma corta el flujo serían nuestros 3 pasos, crear el imputador, entrenarlo y aplicarlo:

# %%
imputador1=SimpleImputer(missing_values=np.nan,strategy='median') # creamos
imputador1.fit(dfB)                                               # entrenamos
B_Transformado=imputador1.transform(dfB)                          # imputamos

B_Transformado
# Out:
# array([[1., 5., 4., 3.],
#        [3., 3., 2., 4.],
#        [7., 3., 0., 4.],
#        [4., 2., 4., 1.],
#        [3., 0., 4., 8.],
#        [2., 7., 5., 4.]])

# %% [markdown]
# Hemos obtenido los valores ya transformados pero como array de Numpy, si es necesario podemos transformarlo en un dataFrame con los mismos nombres de columnas que el original.

# %%
# lo que sigue es sólo para rearmarlo como DataFrame, si es necesario y luego mostrarlo:
dfB_Transformado=pd.DataFrame(B_Transformado, columns=dfB.columns)
dfB_Transformado
# Out:
#    col1  col2  col3  col4
# 0   1.0   5.0   4.0   3.0
# 1   3.0   3.0   2.0   4.0
# 2   7.0   3.0   0.0   4.0
# 3   4.0   2.0   4.0   1.0
# 4   3.0   0.0   4.0   8.0
# 5   2.0   7.0   5.0   4.0

# %% [markdown]
# Como puede observar, realmente muy sencillo! Veamos algunos casos más.

# %% [markdown]
# #### Ejercicio 2
#
# Dado el DataFrame dfC, impute la mediana de cada columna a los valores que tienen valor -1. Al imputador llámelo imputador2 y guarde los resultados en un nuevo dataFrame denominado dfC_Transformado

# %%
dfC=pd.DataFrame([[3,7,-1,0],[2,-1,5,4],[0,0,0,0],[-1,5,4,2],[2,6,8,1],[2,1,3,2]])
dfC.columns=['A','B','C','D']
dfC
# Out:
#    A  B  C  D
# 0  3  7 -1  0
# 1  2 -1  5  4
# 2  0  0  0  0
# 3 -1  5  4  2
# 4  2  6  8  1
# 5  2  1  3  2

# %% [markdown]
# #### Respuesta Ejercicio 2
#
# En forma corta el flujo sería:

# %%
imputador2 = SimpleImputer(strategy='median',missing_values=-1)
imputador2.fit(dfC)
imputador2.statistics_
# Out:
# array([2. , 5. , 4. , 1.5])

# %%
dfC_transformado = pd.DataFrame(imputador2.transform(dfC),columns=dfC.columns) #hice la tranfromacion dentro de la creacion del data frame
dfC_transformado
# Out:
#      A    B    C    D
# 0  3.0  7.0  4.0  0.0
# 1  2.0  5.0  5.0  4.0
# 2  0.0  0.0  0.0  0.0
# 3  2.0  5.0  4.0  2.0
# 4  2.0  6.0  8.0  1.0
# 5  2.0  1.0  3.0  2.0

# %% [markdown]
# #### Ejercicio 3
# Vamos a complicarla un poco:
#
#
# Dado el DataFrame dfC:
#
# - En las columnas A y C, impute a los valores -1, el promedio. Llame a este imputador imputador_prom
# - En las columnas B y D impute a los valores -1 la mediana. Llame a este imputador imputador_mediana
#
# Guarde los resutados en un nuevo DataFrame denominado dfC_Transformado2

# %% [markdown]
# #### Respuesta Ejercicio 3:
#
# Como el imputador de sklearn trabaja sobre **todas** las columnas ... y queremos hacer imputaciones distintas a algunas columnas ... deberemos dividir nuestro dataframe original en dos partes, uno que tenga las columnas A y C y otro que tenga las columnas B y D.

# %%
dfC1=dfC[['A','C']]
dfC1
# Out:
#    A  C
# 0  3 -1
# 1  2  5
# 2  0  0
# 3 -1  4
# 4  2  8
# 5  2  3

# %% [markdown]
# Ahora trabajamos con las imputaciones para estas columnas:

# %%
imputadorC1= SimpleImputer(missing_values=-1,strategy='mean')
imputadorC1.fit(dfC1)
imputadorC1.statistics_
# Out:
# array([1.8, 4. ])

# %%
dfC1_transformado= pd.DataFrame(imputadorC1.transform(dfC1),columns=dfC1.columns)
dfC1_transformado
# Out:
#      A    C
# 0  3.0  4.0
# 1  2.0  5.0
# 2  0.0  0.0
# 3  1.8  4.0
# 4  2.0  8.0
# 5  2.0  3.0

# %% [markdown]
# Ahora repetimos las operaciones para las columnas B y D:

# %%
dfC2 = dfC[['B','D']]
dfC2
# Out:
#    B  D
# 0  7  0
# 1 -1  4
# 2  0  0
# 3  5  2
# 4  6  1
# 5  1  2

# %% [markdown]
# Ahora trabajamos con las imputaciones para estas columnas:

# %%
imputadorC2 = SimpleImputer(missing_values=-1,strategy='median')
imputadorC2.fit(dfC2)
imputadorC2.statistics_
# Out:
# array([5. , 1.5])

# %%
dfC2_transformado = pd.DataFrame(imputadorC2.transform(dfC2), columns=dfC2.columns)
dfC2_transformado
# Out:
#      B    D
# 0  7.0  0.0
# 1  5.0  4.0
# 2  0.0  0.0
# 3  5.0  2.0
# 4  6.0  1.0
# 5  1.0  2.0

# %% [markdown]
# Si lo necesitamos (no siempre es necesario), podríamos reconstruir el DataFrame con todas sus columnas pero ahora transformadas, para ello deberemos  utilizar un poco de Pandas ... podemos usar pd.concat() ... (hay muchas otras formas de hacerlo):

# %%
dfC_Final = pd.concat([dfC1_transformado,dfC2_transformado],axis=1)
dfC_Final
# Out:
#      A    C    B    D
# 0  3.0  4.0  7.0  0.0
# 1  2.0  5.0  5.0  4.0
# 2  0.0  0.0  0.0  0.0
# 3  1.8  4.0  5.0  2.0
# 4  2.0  8.0  6.0  1.0
# 5  2.0  3.0  1.0  2.0

# %% [markdown]
# #### Ejercicio 4
#
# Supongamos que tenemos un DataFrame como el dfD:

# %%
dfD=pd.DataFrame([[3,2,'Si'],[np.nan,6,'No'],[5,8,'Si'],[0,np.nan,'Si'],[np.nan,4,'No'],[6,6,np.nan],[4,12,'No'],[2,9,np.nan]])
dfD.columns=['x1','x2','x3']
dfD
# Out:
#     x1    x2   x3
# 0  3.0   2.0   Si
# 1  NaN   6.0   No
# 2  5.0   8.0   Si
# 3  0.0   NaN   Si
# 4  NaN   4.0   No
# 5  6.0   6.0  NaN
# 6  4.0  12.0   No
# 7  2.0   9.0  NaN

# %% [markdown]
# Observe que la variable x3 no es numérica, sino categórica.
#
# Queremos imputar el promedio en las columnas numéricas y la moda en las columnas categóricas (esto es un problema bien típico de ML).  Queremos el resultado en un único DataFrame que se llame dfD_Transformado.

# %%
dfD_cat = pd.DataFrame(dfD['x3'])
dfD_cat
# Out:
#     x3
# 0   Si
# 1   No
# 2   Si
# 3   Si
# 4   No
# 5  NaN
# 6   No
# 7  NaN

# %%
imputadorD_cat = SimpleImputer(strategy='most_frequent')#Creo el modelo imputer
imputadorD_cat.fit(dfD_cat)#Lo entreno con los datos de las variables categoricas
imputadorD_cat.statistics_#Hago que me muestre cual resultado obtuvo
dfD_cat_transformado = pd.DataFrame(imputadorD_cat.transform(dfD_cat),columns=(['x3'])) # Creo el nuevo DF
dfD_cat_transformado# Muestro el nuevo DF
# Out:
#    x3
# 0  Si
# 1  No
# 2  Si
# 3  Si
# 4  No
# 5  No
# 6  No
# 7  No

# %%
dfD_num = dfD[['x1','x2']]
dfD_num
# Out:
#     x1    x2
# 0  3.0   2.0
# 1  NaN   6.0
# 2  5.0   8.0
# 3  0.0   NaN
# 4  NaN   4.0
# 5  6.0   6.0
# 6  4.0  12.0
# 7  2.0   9.0

# %%
imputadorD_num = SimpleImputer(strategy='mean')#Creo el modelo con el promedio
imputadorD_num.fit(dfD_num)#lo hago calcular las variables
imputadorD_num.statistics_#Evaluo los resultados
# Out:
# array([3.33333333, 6.71428571])

# %%
dfD_num_transformado = pd.DataFrame( imputadorD_num.transform(dfD_num) ,columns=('x1','x2'))
dfD_num_transformado
# Out:
#          x1         x2
# 0  3.000000   2.000000
# 1  3.333333   6.000000
# 2  5.000000   8.000000
# 3  0.000000   6.714286
# 4  3.333333   4.000000
# 5  6.000000   6.000000
# 6  4.000000  12.000000
# 7  2.000000   9.000000

# %%
dfD_Final = pd.concat([dfD_num_transformado,dfD_cat_transformado],axis=1)
dfD_Final
# Out:
#          x1         x2  x3
# 0  3.000000   2.000000  Si
# 1  3.333333   6.000000  No
# 2  5.000000   8.000000  Si
# 3  0.000000   6.714286  Si
# 4  3.333333   4.000000  No
# 5  6.000000   6.000000  No
# 6  4.000000  12.000000  No
# 7  2.000000   9.000000  No

# %% [markdown]
# #### Ejercicio 6
# Supongamos que contamos con el DataFrame dfE:

# %%
dfE=pd.DataFrame([[1.5,'Si',2,True],[4,'No',7,False],[np.nan,'Si',9,False],[3.5,np.nan,8,np.nan],[6,'Si',np.nan,True]])
dfE.columns=['x1','x2','x3','x4']
dfE
# Out:
#     x1   x2   x3     x4
# 0  1.5   Si  2.0   True
# 1  4.0   No  7.0  False
# 2  NaN   Si  9.0  False
# 3  3.5  NaN  8.0    NaN
# 4  6.0   Si  NaN   True

# %% [markdown]
# y queremos imputar:
# - el **promedio** a las numéricas y,
# - la **moda** a las categóricas, de texto y booleanas,
# - el resultado lo queremos en el DataFrame denominado dfE_Transformado

# %% [markdown]
# Veamos de qué tipo es cada columna con info()

# %%
dfE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      4 non-null      float64
#  1   x2      4 non-null      object
#  2   x3      4 non-null      float64
#  3   x4      4 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 288.0+ bytes

# %% [markdown]
# - A x1 y x3 las tomó como float64, es decir numéricas, si hubieran sido números enteros las hubier considerado como int64. No hay diferencia para la imputación.
#
# - A x2 la tomó como object, que es el tipo correspondiente a los textos y categóricas.
#
# - Fíjese que a la columna x4 la tomó como object cuando los valores eran esencialmente booleanos, esto ocurrió por la presencial del nan. Generalmente no traerá problemas porque en ambos casos la imputación suele ser la moda.

# %% [markdown]
# Esta vez no queremos pasar explícitamente los nombres de cada columna a cada trasnformer, sino que buscamos alguna manera de hacerlo programáticamente.
#
# Podemos usar a select_dtypes de Pandas para seleccionar las columnas según el tipo de dato:

# %%
cols_num=dfE.select_dtypes(np.number).columns
# en vez de np.number podriamos haber usado select_dtypes.(include=['int64','float64']).columns
cols_num
# Out:
# Index(['x1', 'x3'], dtype='object')

# %% [markdown]
# Como podemos ver, nos devolvió x1 y x3 como deseábamos. De forma similar:

# %%
cols_cat=dfE.select_dtypes(include=['object','bool']).columns
cols_cat
# Out:
# Index(['x2', 'x4'], dtype='object')

# %% [markdown]
# Nos devolvió x2 y x4

# %% [markdown]
# Ahora sí, estamos listos! Se anima a terminarlo?

# %% [markdown]
# #### Resolución Ejercicio 6

# %% [markdown]
# Son sólo unas pocas líneas de código!

# %%
t1E = ('mod_num',SimpleImputer(strategy='mean'),cols_num)
t2E = ('mod_cat', SimpleImputer(strategy='most_frequent'),cols_cat)

transformador_E_columnas = ColumnTransformer(transformers=[t1E,t2E])

transformador_E_columnas.fit(dfE)
# Out:
# ColumnTransformer(transformers=[('mod_num', SimpleImputer(),
#                                  Index(['x1', 'x3'], dtype='object')),
#                                 ('mod_cat',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  Index(['x2', 'x4'], dtype='object'))])

# %% [markdown]
# Lo transformamos en un DataFrame de Pandas según lo solicitado:

# %%
dfE_transformado = pd.DataFrame(transformador_E_columnas.transform(dfE), columns= dfE.columns)
dfE_transformado
# Out:
#      x1   x2  x3     x4
# 0   1.5  2.0  Si   True
# 1   4.0  7.0  No  False
# 2  3.75  9.0  Si  False
# 3   3.5  8.0  Si  False
# 4   6.0  6.5  Si   True

# %% [markdown]
# Listo!
