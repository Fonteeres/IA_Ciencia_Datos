# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/IA y Ciencia de Datos/Semestre 3/Mineria de datos/21 06 2022/data/people.csv')

# %%
df
# Out:
#        id              full_name gender    country       car_make  \
# 0       1         Jakie Ilyinski      M   Colombia        Porsche
# 1       2  Constantino Placstone      M     Russia          Lexus
# 2       3       Cornie Philipart      M  Indonesia           Audi
# 3       4            Brear Heads      F   Bulgaria           Ford
# 4       5      Magda Crosthwaite      F      China          Honda
# ..    ...                    ...    ...        ...            ...
# 995   996          Sigmund Eldin      M       Iran            GMC
# 996   997        Elset Speachley      M      China  Mercedes-Benz
# 997   998        Granger Daniaud      M      China            Kia
# 998   999         Franny Murdoch      F    Ukraine          Mazda
# 999  1000         Mercie Biernat      F       Mali         Toyota
#
#                           email
# 0       jilyinski0@blogspot.com
# 1           cplacstone1@php.net
# 2     cphilipart2@homestead.com
# 3    bheads3@huffingtonpost.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 977 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         977 non-null    int64
#  1   full_name  977 non-null    object
#  2   gender     977 non-null    object
#  3   country    977 non-null    object
#  4   car_make   977 non-null    object
#  5   email      977 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 53.4+ KB

# %%
df.dropna(inplace=True)

# %%
dfcountry2 = df.groupby('country').value_counts()
dfcountry2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-66b2c6cb7f37> in <module>()
# ----> 1 dfcountry2 = df.groupby('country').value_counts()
#       2 dfcountry2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
dfcountry = pd.DataFrame(df.groupby('country')['id'].count())
dfcountry.sort_values(by='id',ascending=False)
# Out:
#                                    id
# country
# China                             197
# Indonesia                         101
# Russia                             62
# Philippines                        48
# Portugal                           36
# ...                               ...
# Paraguay                            1
# Benin                               1
# Democratic Republic of the Congo    1
# Barbados                            1
# Cambodia                            1
#
# [118 rows x 1 columns]

# %%
dfcountry2[1:]
# Out:
# country
# Aland Islands      1
# Albania            1
# Argentina          9
# Armenia            1
# Australia          1
#                   ..
# United Kingdom     2
# United States     22
# Uzbekistan         1
# Venezuela          4
# Vietnam            8
# Name: id, Length: 117, dtype: int64
