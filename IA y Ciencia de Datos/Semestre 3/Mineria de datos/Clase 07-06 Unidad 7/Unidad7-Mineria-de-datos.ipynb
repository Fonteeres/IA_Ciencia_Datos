# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df_movies = pd.read_csv('/content/drive/MyDrive/Mineria de datos- Semestre 3/Clase 07 06 Unidad 7/ml-latest-small/movies.csv')
df_ratings =  pd.read_csv('/content/drive/MyDrive/Mineria de datos- Semestre 3/Clase 07 06 Unidad 7/ml-latest-small/ratings.csv')

# %%
df_movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
MasVistas = df_ratings.groupby('movieId').count()
MasVistas.sort_values(by='userId',ascending=False).head(5)
#grafico de tortas de las 5 pelis mas vistas y por cuantos
# Out:
#          userId  rating  timestamp
# movieId
# 356         329     329        329
# 318         317     317        317
# 296         307     307        307
# 593         279     279        279
# 2571        278     278        278

# %%
df_Frutas = pd.read_csv('/content/drive/MyDrive/Mineria de datos- Semestre 3/Clase 07 06 Unidad 7/ml-latest-small/frutas.csv')
df_Frutas
# Out:
#    persona    fruta
# 0    pedro  manzana
# 1     juan  naranja
# 2      ana  manzana
# 3   estela  manzana
# 4    luisa  naranja
# 5    jorge     pera
# 6   daniel  manzana
# 7   miguel     pera
# 8  isabela      uva
# 9  julieta  naranja

# %%
df = df_Frutas.groupby('fruta').count()
df['frutas'] = df.index
plt.bar(df['frutas'],df['persona'])
plt.show()
