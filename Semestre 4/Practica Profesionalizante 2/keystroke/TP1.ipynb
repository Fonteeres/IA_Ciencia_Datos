# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
df_Cambio_mano = pd.read_csv('Datos\cidia_pp2_table_tiempos_cambio_mano.csv')
df_Tiempo_Tecla = pd.read_csv('Datos\cidia_pp2_table_tiempos_por_tecla.csv')
df_Usuario = pd.read_csv('Datos\cidia_pp2_table_usuarios.csv')

# %%
df_Cambio_mano = df_Cambio_mano.drop('tiempo_id',axis=1)

# %%
df_Cambio_mano = df_Cambio_mano[df_Cambio_mano['tiempo']<= 3000]
df_Cambio_mano = df_Cambio_mano[df_Cambio_mano['modo'] == 1]
df_Cambio_mano
# Out:
#        usuario  practica  mano  mano_anterior  tiempo  modo
# 0            1         1     1              2      96     1
# 1            1         1     1              2     225     1
# 2            1         1     2              1     160     1
# 3            1         1     1              2      96     1
# 4            1         1     2              1      81     1
# ...        ...       ...   ...            ...     ...   ...
# 82042      106        14     2              1      96     1
# 82043      106        14     1              2      72     1
# 82044      106        14     2              1     256     1
# 82045      106        14     1              2     231     1
# 82046      106        14     2              1      80     1
#
# [45373 rows x 6 columns]

# %%
px.violin(df_Cambio_mano, y='tiempo', color='usuario')

# %%
df_Tiempo_Tecla = df_Tiempo_Tecla.drop('tiempo_id',axis=1)

# %%
df_Tiempo_Tecla= df_Tiempo_Tecla[df_Tiempo_Tecla['modo'] == 1]

# %%
df_Tiempo_Tecla
# Out:
#         usuario  practica  tecla     up   down  anterior  anterior_down  modo
# 0             1         1     69     43      0         0              0     1
# 1             1         1     83    237    157        69              0     1
# 2             1         1     84    458    330        83            157     1
# 3             1         1     65    571    426        84            330     1
# 4             1         1     32    650    572        65            426     1
# ...         ...       ...    ...    ...    ...       ...            ...   ...
# 263642      106        14     65  49951  49871        85          49640     1
# 263643      106        14     82  50272  50184        65          49871     1
# 263644      106        14     73  50384  50264        82          50184     1
# 263645      106        14     79  50528  50385        73          50264     1
# 263646      106        14     46  50919  50919        79          50385     1
#
# [152106 rows x 8 columns]

# %%
df_Tiempo_Tecla['Tiempo_Up'] = df_Tiempo_Tecla['up'] - df_Tiempo_Tecla['anterior_down']
df_Tiempo_Tecla['Tiempo_down'] = df_Tiempo_Tecla['down'] - df_Tiempo_Tecla['anterior_down']

# %%
df_Tiempo_Tecla['Tecla_esp'] = df_Tiempo_Tecla['tecla'].map(chr)
df_Tiempo_Tecla['Tecla_esp_sig'] =  df_Tiempo_Tecla['tecla'].map(chr).shift(-1)

# %%
df_Tiempo_Tecla['Frase_2'] = df_Tiempo_Tecla['Tecla_esp'] + df_Tiempo_Tecla['Tecla_esp_sig']

# %%
df_Tiempo_Tecla.drop('Tecla_esp_sig',axis=1)
# Out:
#         usuario  practica  tecla     up   down  anterior  anterior_down  modo  \
# 0             1         1     69     43      0         0              0     1
# 1             1         1     83    237    157        69              0     1
# 2             1         1     84    458    330        83            157     1
# 3             1         1     65    571    426        84            330     1
# 4             1         1     32    650    572        65            426     1
# ...         ...       ...    ...    ...    ...       ...            ...   ...
# 263642      106        14     65  49951  49871        85          49640     1
# 263643      106        14     82  50272  50184        65          49871     1
# 263644      106        14     73  50384  50264        82          50184     1
# 263645      106        14     79  50528  50385        73          50264     1
# 263646      106        14     46  50919  50919        79          50385     1
#
# ...

# %%
df_Tiempo_Tecla_pivoteado = df_Tiempo_Tecla.pivot(columns='usuario')
df_Tiempo_Tecla_pivoteado
# Out:
#         practica                                      ... Frase_2            \
# usuario      1   62  64  65  66  67  68  69  70  72   ...     93   94   97
# 0            1.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# 1            1.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# 2            1.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# 3            1.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# 4            1.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# ...          ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...     ...  ...  ...
# 263642       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# 263643       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# 263644       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# 263645       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...     NaN  NaN  NaN
# ...

# %%
df_Tiempo_Tecla.groupby(['usuario','practica','Tecla_esp'])['Tecla_esp'].count().reset_index(name='cant')
# Out:
#        usuario  practica Tecla_esp  cant
# 0            1         1              39
# 1            1         1         ,     2
# 2            1         1         .     6
# 3            1         1         0     1
# 4            1         1         1     3
# ...        ...       ...       ...   ...
# 19387      107         1         R    23
# 19388      107         1         S    13
# 19389      107         1         T    10
# 19390      107         1         U    12
# 19391      107         1         V     2
#
# [19392 rows x 4 columns]

# %%
df_Tiempo_Tecla.groupby(['usuario','practica','Frase_2'])['Frase_2'].count().reset_index(name='cant')
# Out:
#        usuario  practica Frase_2  cant
# 0            1         1       1     2
# 1            1         1       6     1
# 2            1         1       9     1
# 3            1         1       A     3
# 4            1         1       C     3
# ...        ...       ...     ...   ...
# 80072      107         1      UI     2
# 80073      107         1      UN     2
# 80074      107         1      UR     2
# 80075      107         1      US     1
# 80076      107         1      VA     2
#
# [80077 rows x 4 columns]
