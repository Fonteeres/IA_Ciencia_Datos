# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Comparación de tiempos ganadores en atletismo

# %% [markdown]
# El día de hoy vamos a utilizar un set de datos subido a la plataforma de Kaggle, donde se busca comparar el progreso de los tiempos ganadores en las carreras de atletismo de los Juegos Olímpicos a lo largo de los años.
# https://www.kaggle.com/datasets/bonniesindelar/comparing-progress-of-olympic-winning-track-times

# %% [markdown]
# Para comenzar vamos a analizar las carreras de 200 metros llanos de la categoria mujeres.

# %%
df = pd.read_csv(r'C:\Users\Alumno\IA_Ciencia_Datos\Semestre 4\Aprendizaje Automatico 2\archive\women200.csv')

# %% [markdown]
# Solo nos interesa quedarnos con el año y los tiempos.

# %%
df = df[['Year','Result']].dropna()
df
# Out:
#       Year  Result
# 0   1948.0   24.40
# 1   1952.0   23.70
# 2   1956.0   23.40
# 3   1960.0   24.00
# 4   1964.0   23.00
# 5   1968.0   22.50
# 6   1972.0   22.40
# 7   1976.0   22.37
# 8   1980.0   22.03
# 9   1984.0   21.81
# 10  1992.0   21.81
# 11  1996.0   22.12
# 12  2000.0   22.27
# 13  2004.0   22.05
# 14  2008.0   21.74
# 15  2012.0   21.88
# 16  2016.0   21.78
# 17  2021.0   21.53

# %% [markdown]
# Podemos graficar cada punto en el plano y marcar la tendencia de estos con el modelito de regresión más sencillo, el calculo de los mínimos cuadrados OLS (Ordinary Least Squares)

# %%
px.scatter(x=df['Year'], y=df['Result'], trendline="ols")

# %% [markdown]
# Consigna:
# -  Elaborar un modelo de regresión lineal que prediga los valores de los resultados. Calcular el RMSE.
# - Crear nuevas varibles con las potencias de la x hasta 8 (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html)
# - Elaborar un nuevo modelo de regresión con estas variables
# - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html#sklearn.linear_model.Ridge
# -https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html#sklearn.linear_model.Lasso
# -https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html#sklearn.linear_model.ElasticNet

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
#Creo el modelo el 8 es el maximo grado del polinomio que voy a usar
poly = PolynomialFeatures(8) #Este modelo agrega mas grados y le permite mas libertad al modelo para adaptarse a los datos
#Creo las variable
X = df[['Year']]
y = df[['Result']]
X = poly.fit_transform(X)
reg = LinearRegression().fit(X, y)
reg.score(X, y) #R2
# Out:
# 0.9102418978806935

# %%
a = reg.predict(X)
mean_squared_error(a, y, squared=False)
# Out:
# 0.2484489809910849

# %%
from sklearn.linear_model import Ridge
clf = Ridge(alpha=100).fit(X, y)
b = clf.predict(X)
mean_squared_error(y,b,squared=False)
# Out:
# 0.4958564004939856

# %%
from sklearn import linear_model
clfL = linear_model.Lasso(alpha=0.11).fit(X, y)
c = clf.predict(X)
mean_squared_error(y,c,squared=False)
# Out:
# c:\Users\Alumno\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3420093984674788, tolerance: 0.001237864999999999
# 0.4958564004939856

# %%
from sklearn.linear_model import ElasticNet
regr = ElasticNet(random_state=0,l1_ratio=0).fit(X, y)
d = regr.predict(X)
mean_squared_error(y,d,squared=False)
# Out:
# c:\Users\Alumno\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2131901783616412, tolerance: 0.001237864999999999
# 0.3374388104414839

# %% [markdown]
# # Conclusion

# %% [markdown]
# Estaba buscando llegar al punto en el que el modelo con regresion lineal sin utilizar la regularizacion sobre aprende con los datos y termina en un R2 de 1.0 y en cambio cuando la regularizacion restinje el valor que toman las variables que acompañan las x y eso no permite que el modelo sobre aprenda con los datos.
