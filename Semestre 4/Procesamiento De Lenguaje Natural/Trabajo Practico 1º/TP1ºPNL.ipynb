# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Noticias Verdaderas y Falsas.xlsx")
df
# Out:
#       class                                               Text
# 0      True   Algunas de las voces extremistas más conocida...
# 1      True   Después de casi dos años y medio de luchas po...
# 2      True  Dos periodistas birmanos de la agencia Reuters...
# 3      True  El Cuerpo Nacional de Policía ha detenido a cu...
# 4      True  El desfile de la firma en Roma se convierte en...
# ...     ...                                                ...
# 1995   True   El Consejo de Gobierno ha dado su visto bueno...
# 1996   True   Investigadores valencianos han desarrollado u...
# 1997   True   Los arrestados actuaban en coches y en establ...
# 1998   True   El Rey ha encargado este miércoles a Pedro Sá...
# 1999   True   Las pruebas realizadas en el Centro Nacional ...
#
# [2000 rows x 2 columns]

# %%
lower = pd.DataFrame()
for index, texto in df.iterrows():
    print(index,texto)
    #lower.append(texto,ignore_index=True)

#lower
# Out:
# 0 class                                                 True
# Text      Algunas de las voces extremistas más conocida...
# Name: 0, dtype: object
# 1 class                                                 True
# Text      Después de casi dos años y medio de luchas po...
# Name: 1, dtype: object
# 2 class                                                 True
# Text     Dos periodistas birmanos de la agencia Reuters...
# Name: 2, dtype: object
# 3 class                                                 True
# Text     El Cuerpo Nacional de Policía ha detenido a cu...
# Name: 3, dtype: object
# 4 class                                                 True
# Text     El desfile de la firma en Roma se convierte en...
# Name: 4, dtype: object
# 5 class                                                 True
# Text     El miedo a la pérdida de identidad y la aversi...
# Name: 5, dtype: object
# 6 class                                                 True
# ...
